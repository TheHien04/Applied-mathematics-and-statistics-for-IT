# %% [markdown]
# # Project 01 - Color Compression

# %% [markdown]
# ## Thông tin sinh viên

# %% [markdown]
# - Họ và tên: Nguyễn Thế Hiển
# - MSSV: 22127107
# - Lớp: 22CLC08

# %% [markdown]
# ## Import các thư viện liên quan

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Helper functions

# %%
def read_img(img_path):
    """
    Read image from img_path

    Parameters
    ----------
    img_path : str
        Path of image

    Returns
    -------
        Image (2D)
    """

    # YOUR CODE HERE
    image = Image.open(img_path).convert("RGB")
    image_2d = np.array(image, dtype=np.float64)
    return image_2d


def show_img(img_2d):
    """
    Show image

    Parameters
    ----------
    img_2d : np.ndarray
        Image (2D)
    """

    # YOUR CODE HERE
    plt.imshow(np.clip(img_2d, 0, 255).astype(np.uint8))
    plt.axis("off")
    plt.show()


def save_img(img_2d, img_path):
    """
    Save image to img_path

    Parameters
    ----------
    img_2d : np.ndarray
        Image (2D)
    img_path : str
        Path of image
    """

    # YOUR CODE HERE
    image = Image.fromarray(np.clip(img_2d, 0, 255).astype(np.uint8))
    image.save(img_path)


def convert_img_to_1d(img_2d):
    """
    Convert 2D image to 1D image

    Parameters
    ----------
    img_2d : np.ndarray
        Image (2D)

    Returns
    -------
        Image (1D)
    """

    # YOUR CODE HERE
    return img_2d.reshape((-1, img_2d.shape[2]))


def kmeans(img_1d, k_clusters, max_iter, init_centroids="random"):
    """
    K-Means algorithm

    Parameters
    ----------
    img_1d : np.ndarray with shape=(height * width, num_channels)
        Original (1D) image
    k_clusters : int
        Number of clusters
    max_iter : int
        Max iterator
    init_centroids : str, default="random"
        The method used to initialize the centroids for K-means clustering
        "random" --> Centroids are initialized with random values between 0 and 255 for each channel
        "in_pixels" --> A random pixel from the original image is selected as a centroid for each cluster

    Returns
    -------
    centroids : np.ndarray with shape=(k_clusters, num_channels)
        Stores the color centroids for each cluster
    labels : np.ndarray with shape=(height * width, )
        Stores the cluster label for each pixel in the image
    """

    # YOUR CODE HERE
    n_pixels, n_channels = img_1d.shape
    img_1d = img_1d.astype(np.float64)

    if init_centroids == "random":
        centroids = np.random.uniform(0, 255, size=(k_clusters, n_channels))
    elif init_centroids == "in_pixels":
        idx = np.random.choice(n_pixels, size=k_clusters, replace=False)
        centroids = img_1d[idx].copy()
    else:
        raise ValueError("init_centroids must be 'random' or 'in_pixels'")

    labels = np.zeros(n_pixels, dtype=np.int32)

    for _ in range(max_iter):
        # Squared Euclidean distance in RGB space
        distances = ((img_1d[:, None, :] - centroids[None, :, :]) ** 2).sum(axis=2)
        labels = np.argmin(distances, axis=1)

        new_centroids = centroids.copy()
        for k in range(k_clusters):
            members = img_1d[labels == k]
            if len(members) > 0:
                new_centroids[k] = members.mean(axis=0)
            # else: retain previous centroid for empty cluster

        if np.allclose(centroids, new_centroids, rtol=0.0, atol=1e-4):
            centroids = new_centroids
            break
        centroids = new_centroids

    return centroids, labels


def generate_2d_img(img_2d_shape, centroids, labels):
    """
    Generate a 2D image based on K-means cluster centroids

    Parameters
    ----------
    img_2d_shape : tuple (height, width, 3)
        Shape of image
    centroids : np.ndarray with shape=(k_clusters, num_channels)
        Store color centroids
    labels : np.ndarray with shape=(height * width, )
        Store label for pixels (cluster's index on which the pixel belongs)

    Returns
    -------
        New image (2D)
    """

    # YOUR CODE HERE
    new_img_1d = centroids[labels]
    new_img_2d = new_img_1d.reshape(img_2d_shape)
    return np.clip(new_img_2d, 0, 255).astype(np.uint8)


def reconstruction_error(img_1d, centroids, labels):
    """
    Mean squared error between original pixels and assigned centroids.
    """
    reconstructed = centroids[labels]
    return float(np.mean((img_1d.astype(np.float64) - reconstructed) ** 2))


# Your additional functions here

# %% [markdown]
# ## Your tests

# %%
# YOUR CODE HERE
def test_functions(img_path="test_image.jpg"):
    """
    Smoke test for the color-compression pipeline.
    Update img_path to a valid local image before running.
    """
    img_2d = read_img(img_path)
    assert img_2d is not None, "Failed to read image"
    assert len(img_2d.shape) == 3 and img_2d.shape[2] == 3, "Image is not a valid RGB image"

    print("Displaying original image:")
    show_img(img_2d)

    img_1d = convert_img_to_1d(img_2d)
    assert img_1d.shape[0] == img_2d.shape[0] * img_2d.shape[1], "Conversion to 1D failed"
    assert img_1d.shape[1] == 3, "Conversion to 1D failed: number of channels should be 3"

    k_clusters = 5
    max_iter = 100

    for init_method in ("random", "in_pixels"):
        centroids, labels = kmeans(img_1d, k_clusters, max_iter, init_centroids=init_method)
        assert centroids.shape == (k_clusters, img_1d.shape[1]), f"Centroids shape mismatch for {init_method}"
        assert labels.shape == (img_1d.shape[0],), f"Labels shape mismatch for {init_method}"

        new_img_2d = generate_2d_img(img_2d.shape, centroids, labels)
        assert new_img_2d.shape == img_2d.shape, f"Generated image shape mismatch for {init_method}"

        mse = reconstruction_error(img_1d, centroids, labels)
        print(f"Displaying new image with '{init_method}' initialization | MSE = {mse:.4f}")
        show_img(new_img_2d)

        save_img(new_img_2d, f"test_image_result_{init_method}.png")
        save_img(new_img_2d, f"test_image_result_{init_method}.pdf")

    print("All tests passed.")

# %% [markdown]
# ## Main FUNCTION

# %%
# YOUR CODE HERE
def main():
    img_path = input("Enter the path to the image: ").strip()
    k_clusters = int(input("Enter the number of clusters (k): ").strip())
    max_iter = int(input("Enter the maximum number of iterations: ").strip())

    print("Initialization methods: 0) random  1) in_pixels  2) both")
    init_choice = input("Choose initialization method [0/1/2]: ").strip()
    init_map = {"0": ["random"], "1": ["in_pixels"], "2": ["random", "in_pixels"]}
    if init_choice not in init_map:
        raise ValueError("Invalid initialization choice. Please enter 0, 1, or 2.")
    init_methods = init_map[init_choice]

    print("Output formats: png | jpg | pdf")
    output_format = input("Choose output format: ").strip().lower()
    if output_format not in {"png", "jpg", "pdf"}:
        raise ValueError("Invalid output format. Please choose png, jpg, or pdf.")

    save_path_base = input("Enter the base path to save the new image (without extension): ").strip()

    img_2d = read_img(img_path)
    img_1d = convert_img_to_1d(img_2d)

    print("Original Image:")
    show_img(img_2d)
    unique_colors = len(np.unique(img_1d.astype(np.uint8), axis=0))
    print(f"Image shape: {img_2d.shape} | Unique colors: {unique_colors}")

    for init_method in init_methods:
        centroids, labels = kmeans(img_1d, k_clusters, max_iter, init_centroids=init_method)
        new_img_2d = generate_2d_img(img_2d.shape, centroids, labels)
        mse = reconstruction_error(img_1d, centroids, labels)

        print(f"Compressed image | init='{init_method}' | k={k_clusters} | MSE={mse:.4f}")
        show_img(new_img_2d)

        save_path = f"{save_path_base}_{init_method}.{output_format}"
        if output_format == "jpg":
            Image.fromarray(new_img_2d).save(save_path, format="JPEG", quality=95)
        else:
            save_img(new_img_2d, save_path)
        print(f"Saved: {save_path}")

# %%
# Call main function
main()
